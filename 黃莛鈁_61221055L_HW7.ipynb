# %% [markdown]
# <a href="https://colab.research.google.com/github/TingfangHuang/GenAIHumanities/blob/main/%E9%BB%83%E8%8E%9B%E9%88%81_61221055L_HW7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HW7_語音模型

# %% [markdown]
# ## ✅ 任務一：語音轉文字 + 摘要（ASR + Summarization）(50%)
#
# ### 📌 任務說明：
# 1. 使用 Whisper 模型（建議：`openai/whisper-small`）將一段指定語音檔轉換成文字。
# 2. 使用文字摘要模型（建議：`Pegasus` 或 `T5`）對轉錄後的文字進行自動摘要。
#
# ---
#
# ### 📤 作業繳交內容：
#
# #### 一、模型生成的文字內容
#
# #### 二、LLM 生成的摘要（限 1～3 句）
#
# #### 三、回答問題：
#
# - 你覺得語音轉文字的準確度如何？有哪些地方辨識得不夠好？可能原因是什麼？
# - 生成的摘要有抓到重點嗎？哪些地方可以改進？

# %% [markdown]
# 音檔連結
# https://drive.google.com/file/d/1V7MT56GThk0-ONClr_EFsi_Mo2jBHKXI/view?usp=drive_link

# %%
# !gdown 1V7MT56GThk0-ONClr_EFsi_Mo2jBHKXI
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1V7MT56GThk0-ONClr_EFsi_Mo2jBHKXI
# To: /content/hw7_lecture.m4a
# 100% 533k/533k [00:00<00:00, 122MB/s]

# %%
from google.colab import files

uploaded = files.upload()  # 選擇你的語音檔 (mp3, wav, m4a...)
file_name = list(uploaded.keys())[0]
print(f"已上傳：{file_name}")
# Out:
#      <input type="file" id="files-0dd958b6-3a6a-4417-8fb4-765d9d50964c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0dd958b6-3a6a-4417-8fb4-765d9d50964c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # 摘要
# # 的概念有幾個應用？言語語音處理系統？用

# %% [markdown]
# ## 🎙️ 任務二：聲音克隆（Voice Cloning）（50%)
#
# ### 📌 任務說明：
# 請使用你自己的語音樣本進行「聲音克隆」，讓 AI 模仿你的聲音講出新的句子。
#
# #### 任務步驟：
# 1. 錄製一段自己的語音樣本（5～10 秒，語句自由發揮）
# 2. 選擇兩個不同的聲音克隆工具（例如：`Tortoise TTS`、`Coqui TTS`）
# 3. 使用這兩個工具分別模仿你的聲音，讓 AI 說出你自訂的一段新句子
# 4. 比較兩種工具的效果
#
# ---
#
# ### 📤 作業繳交內容：
#
# #### 一、原始語音樣本（音檔）
#
# #### 二、兩個模型生成的模仿語音（音檔）
#
# #### 三、回答問題：
#
# - AI 合成的聲音和你的聲音有多像？
# - 這兩個模型有什麼差異？哪一個表現比較好？為什麼？
# - 哪些部分可以進一步改進？

# %%
from google.colab import files

uploaded = files.upload()  # 選擇你的語音檔 (mp3, wav, m4a...)
file_name = list(uploaded.keys())[0]
print(f"已上傳：{file_name}")
# Out:
#      <input type="file" id="files-a1bcd653-15eb-4d9c-bcc9-ed7277ed41a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1bcd653-15eb-4d9c-bcc9-ed7277ed41a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()  # 選擇你的語音檔 (mp3, wav, m4a...)
file_name = list(uploaded.keys())[0]
print(f"已上傳：{file_name}")
# Out:
#      <input type="file" id="files-390849ac-d0e9-4a86-8d06-a947f13eff76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-390849ac-d0e9-4a86-8d06-a947f13eff76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 1. 我最後使用resemble AI做聲音克隆。發現AI的聲音比較圓潤，我本人的聲音比較高，但很令我驚訝的是，在第一次聽到的時候真的覺得像我本人的聲音。
# 2. 由於只有使用一個模型，並且這個工具是需要付費才能做更多聲音克隆的。但我覺得免費的版本就已經跟我本人的聲音很相像了。我認為需要改進的是希望系統可以有說中文的聲音克隆，這樣感覺比較好做對比。
